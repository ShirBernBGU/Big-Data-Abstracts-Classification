# %% [markdown]
# # installations

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.14.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.2)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.32.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.11.15)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3

# %% [markdown]
# # uploading data

# %%
import pandas as pd

# Use raw string (r'...') to avoid issues with backslashes in Windows paths
file_path = r'FilteredData100.xlsx'

# Read the Excel file into a DataFrame
df = pd.read_excel(file_path)

# Preview the first few rows
df.head()
# Out:
#    Y1  Y2    Y    Domain                     area  \
# 0   0  12   12       CS    Symbolic computation
# 1   5   2   74  Medical     Alzheimer's Disease
# 2   4   7   68    Civil          Green Building
# 3   1  10   26      ECE          Electric motor
# 4   5  43  115  Medical     Parkinson's Disease
#
#                                             keywords  \
# 0   (2+1)-dimensional non-linear optical waves; e...
# 1   Aging; Tau; Amyloid; PET; Alzheimer's disease...
# 2   LED lighting system; PV system; Distributed l...
# 3   NdFeB magnets; Electric motor; Electric vehic...
# 4   Parkinson's disease; dyskinesia; adenosine A(...
#
#                                             Abstract
# 0  (2 + 1)-dimensional non-linear optical waves t...
# 1  (beta-amyloid (A beta) and tau pathology becom...
# 2  (D)ecreasing of energy consumption and environ...
# 3  (Hybrid) electric vehicles are assumed to play...
# 4  (L)-3,4-Dihydroxyphenylalanine ((L)-DOPA) rema...

# %%
import os, random, numpy as np, pandas as pd, torch
from datasets import Dataset, DatasetDict
from sklearn.model_selection import train_test_split
from transformers import (AutoTokenizer, AutoModelForSequenceClassification,
                          TrainingArguments, Trainer, DataCollatorWithPadding)
import evaluate

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
SEED = 42

# %% [markdown]
# ## TF-IDF With XGBoost

# %%
# Two-step 70/15/15 split on 'area'
train_df, temp_df = train_test_split(
    df,
    test_size=0.30,
    stratify=df["Domain"],
    random_state=SEED
)
val_df, test_df = train_test_split(
    temp_df,
    test_size=0.50,
    stratify=temp_df["Domain"],
    random_state=SEED
)

# %% [markdown]
# ### On Domain and Area:

# %%
def run_ngram_experiment(ngram_range, train_df, val_df, test_df, label_encoder, label_column, seed=SEED):
    print(f"\n=== Evaluating on label column: '{label_column}' | N-gram range: {ngram_range} ===")

    # TF-IDF vectorization
    vectorizer = TfidfVectorizer(ngram_range=ngram_range, max_features=1000000)
    X_train = vectorizer.fit_transform(train_df["Abstract"])
    X_val   = vectorizer.transform(val_df["Abstract"])

    # Encode labels
    y_train = label_encoder.fit_transform(train_df[label_column])
    y_val   = label_encoder.transform(val_df[label_column])

    # Train model
    model = XGBClassifier(random_state=seed, use_label_encoder=False, eval_metric="mlogloss")
    model.fit(X_train, y_train)

    # Evaluate on validation
    val_preds = model.predict(X_val)
    val_acc = accuracy_score(y_val, val_preds)
    print(f"Validation Accuracy: {val_acc:.4f}")
    print("Validation Classification Report:")
    print(classification_report(y_val, val_preds, target_names=label_encoder.classes_))

# %% [markdown]
# Lowercases the text
#
# Tokenizes using a regular expression: words of 2+ characters (\b\w\w+\b)
#
# Removes punctuation
#
# Builds unigrams & bigrams from the tokens

# %%
label_encoder = LabelEncoder()
for label_col in ["Domain", "area"]:
    for ngram_range in [(1, 1), (2, 2), (1, 2)]:
        run_ngram_experiment(ngram_range, train_df, val_df, test_df, label_encoder, label_col)
# Out:
# === Evaluating on label column: 'Domain' | N-gram range: (1, 1) ===
# /home/shirbern/.conda/envs/shir_env_22_may/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [16:04:13] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Validation Accuracy: 0.8786
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#           CS        0.89      0.93      0.91       971
#        Civil        0.91      0.87      0.89       633
#          ECE        0.92      0.90      0.91       807
#          MAE        0.89      0.86      0.88       495
#      Medical        0.86      0.90      0.88      2165
#  Psychology         0.86      0.83      0.84      1071
# biochemistry        0.87      0.83      0.85       851
#
#      accuracy                           0.88      6993
#     macro avg       0.89      0.87      0.88      6993
#  weighted avg       0.88      0.88      0.88      6993
#
#
# === Evaluating on label column: 'Domain' | N-gram range: (2, 2) ===
# /home/shirbern/.conda/envs/shir_env_22_may/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [16:09:03] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Validation Accuracy: 0.8268
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#           CS        0.88      0.85      0.86       971
#        Civil        0.94      0.80      0.86       633
#          ECE        0.87      0.87      0.87       807
#          MAE        0.91      0.77      0.83       495
#      Medical        0.75      0.91      0.82      2165
#  Psychology         0.83      0.71      0.77      1071
# biochemistry        0.88      0.74      0.80       851
#
#      accuracy                           0.83      6993
#     macro avg       0.86      0.81      0.83      6993
#  weighted avg       0.84      0.83      0.83      6993
#
#
# === Evaluating on label column: 'Domain' | N-gram range: (1, 2) ===
# /home/shirbern/.conda/envs/shir_env_22_may/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [16:19:43] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Validation Accuracy: 0.8899
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#           CS        0.92      0.93      0.92       971
#        Civil        0.93      0.88      0.91       633
#          ECE        0.93      0.94      0.93       807
#          MAE        0.90      0.88      0.89       495
#      Medical        0.86      0.91      0.89      2165
#  Psychology         0.87      0.84      0.85      1071
# biochemistry        0.88      0.82      0.85       851
#
#      accuracy                           0.89      6993
#     macro avg       0.90      0.89      0.89      6993
#  weighted avg       0.89      0.89      0.89      6993
#
#
# === Evaluating on label column: 'area' | N-gram range: (1, 1) ===
# /home/shirbern/.conda/envs/shir_env_22_may/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [16:34:39] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Validation Accuracy: 0.7616
# Validation Classification Report:
#                                     precision    recall  f1-score   support
#
#                        Addiction         0.60      0.50      0.55        42
#                 Algorithm design         0.63      0.67      0.65        57
#                        Allergies         0.91      0.89      0.90        55
#              Alzheimer's Disease         0.77      0.87      0.82        54
#             Ambient Intelligence         0.79      0.88      0.83        56
#         Analog signal processing         0.80      0.81      0.81        64
#           Ankylosing Spondylitis         0.85      0.60      0.70        47
#  Antisocial personality disorder         0.75      0.75      0.75        52
#                          Anxiety         0.49      0.37      0.42        46
#                           Asthma         0.70      0.57      0.63        49
#                Atopic Dermatitis         0.81      0.50      0.62        34
#              Atrial Fibrillation         0.79      0.79      0.79        38
#                        Attention         0.69      0.79      0.73        61
#                           Autism         0.58      0.53      0.55        40
#                   Bioinformatics         0.83      0.67      0.74        52
#                 Bipolar Disorder         0.58      0.43      0.49        42
#                    Birth Control         0.74      0.82      0.78        39
#  Borderline personality disorder         0.46      0.45      0.46        53
#                           Cancer         0.44      0.66      0.53        47
#                     Cell biology         0.65      0.61      0.63        85
#                      Child abuse         0.78      0.75      0.77        53
#                Children's Health         0.73      0.78      0.75        45
#                Computer graphics         0.67      0.80      0.73        51
#             Computer programming         0.81      0.96      0.88        56
#                  Computer vision         0.84      0.68      0.75        76
#          Construction Management         0.84      0.84      0.84        68
#              Control engineering         0.75      0.68      0.71        53
#                  Crohn's Disease         0.79      0.86      0.82        35
#              Parkinson's Disease         0.83      0.88      0.85        43
#                Person perception         0.66      0.53      0.59        77
#                Polycythemia Vera         0.88      0.26      0.40        27
#        Polymerase chain reaction         0.72      0.85      0.78        95
#                        Prejudice         0.56      0.62      0.59        61
#             Prenatal development         0.83      0.84      0.83        68
#                  Problem-solving         0.75      0.79      0.77        58
#               Prosocial behavior         0.71      0.63      0.67        46
#                        Psoriasis         0.67      0.60      0.63        20
#              Psoriatic Arthritis         0.59      0.54      0.57        24
#             Rainwater Harvesting         0.97      0.97      0.97        58
#             Relational databases         0.90      0.89      0.90        63
#                   Remote Sensing         0.82      0.84      0.83        63
#             Rheumatoid Arthritis         0.52      0.35      0.42        34
#                  Satellite radio         0.87      0.87      0.87        15
#                    Schizophrenia         0.62      0.49      0.55        68
#      Seasonal affective disorder         0.71      0.77      0.73        47
#                    Senior Health         0.76      1.00      0.87        13
#                Signal-flow graph         0.98      0.88      0.92        48
#                        Skin Care         0.89      0.85      0.87        46
#                   Smart Material         0.83      0.82      0.82        49
#                Smoking Cessation         0.74      0.69      0.71        36
#                 Social cognition         0.45      0.59      0.51        51
#             Software engineering         0.78      0.77      0.77        64
#                     Solar Energy         0.73      0.78      0.75        51
#                Southern blotting         1.00      0.97      0.99        74
#                  Sports Injuries         0.83      0.78      0.80        49
#              Sprains and Strains         0.83      0.71      0.77        28
#       State space representation         0.86      0.88      0.87        43
#               Stealth Technology         1.00      0.88      0.94        25
#            Strength of materials         0.90      0.88      0.89        50
#                Stress Management         0.81      0.78      0.80        78
#                Suspension Bridge         0.83      0.90      0.87        61
#             Symbolic computation         0.79      0.84      0.81        55
#            System identification         0.70      0.78      0.74        67
#                   Thermodynamics         0.83      0.75      0.79        69
#                  Water Pollution         0.85      0.87      0.86        70
#                      Weight Loss         0.83      0.86      0.85        51
#            computer-aided design         0.77      0.80      0.79        55
#                 network security         0.87      0.76      0.81        62
#
#                           accuracy                           0.76      6993
#                          macro avg       0.77      0.75      0.76      6993
#                       weighted avg       0.77      0.76      0.76      6993
#
#
# === Evaluating on label column: 'area' | N-gram range: (2, 2) ===
# /home/shirbern/.conda/envs/shir_env_22_may/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [17:07:28] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Validation Accuracy: 0.7150
# Validation Classification Report:
#                                     precision    recall  f1-score   support
#
#                        Addiction         0.39      0.29      0.33        42
#                 Algorithm design         0.79      0.74      0.76        57
#                        Allergies         0.69      0.62      0.65        55
#              Alzheimer's Disease         0.77      0.89      0.83        54
#             Ambient Intelligence         0.60      0.71      0.65        56
#         Analog signal processing         0.72      0.86      0.79        64
#           Ankylosing Spondylitis         0.79      0.57      0.67        47
#  Antisocial personality disorder         0.90      0.73      0.81        52
#                          Anxiety         0.33      0.20      0.25        46
#                           Asthma         0.62      0.53      0.57        49
#                Atopic Dermatitis         0.75      0.44      0.56        34
#              Atrial Fibrillation         0.78      0.76      0.77        38
#                        Attention         0.44      0.62      0.51        61
#                           Autism         0.52      0.75      0.61        40
#                   Bioinformatics         0.69      0.35      0.46        52
#                 Bipolar Disorder         0.50      0.36      0.42        42
#               Multiple Sclerosis         0.68      0.64      0.66        39
#                    Myelofibrosis         0.57      0.57      0.57        23
#          Nonverbal communication         0.67      0.71      0.69        48
#                Northern blotting         1.00      0.97      0.98       101
#                Operating systems         0.90      0.93      0.92        58
#            Operational amplifier         0.84      0.78      0.81        59
#                   Osteoarthritis         0.71      0.61      0.66        44
#                     Osteoporosis         0.59      0.64      0.61        42
#               Overactive Bladder         0.93      0.90      0.91        58
#                   PID controller         0.94      0.87      0.91        78
#               Parallel computing         0.74      0.62      0.68        79
#                        Parenting         0.55      0.48      0.51        46
#              Parkinson's Disease         0.81      0.88      0.84        43
#                Person perception         0.56      0.53      0.55        77
#                Polycythemia Vera         0.69      0.33      0.45        27
#        Polymerase chain reaction         0.74      0.85      0.79        95
#                        Prejudice         0.42      0.52      0.46        61
#             Prenatal development         0.89      0.81      0.85        68
#                  Problem-solving         0.88      0.84      0.86        58
#               Prosocial behavior         0.61      0.67      0.64        46
#                        Psoriasis         0.32      0.30      0.31        20
#              Psoriatic Arthritis         0.72      0.54      0.62        24
#             Rainwater Harvesting         0.98      0.91      0.95        58
#             Relational databases         0.96      0.81      0.88        63
#                   Remote Sensing         0.72      0.83      0.77        63
#             Rheumatoid Arthritis         0.65      0.44      0.53        34
#                  Satellite radio         1.00      0.80      0.89        15
#                    Schizophrenia         0.60      0.51      0.56        68
#      Seasonal affective disorder         0.80      0.70      0.75        47
#                    Senior Health         1.00      1.00      1.00        13
#                Signal-flow graph         0.93      0.90      0.91        48
#                        Skin Care         0.98      0.87      0.92        46
#                   Smart Material         0.83      0.80      0.81        49
#                Smoking Cessation         0.83      0.67      0.74        36
#                 Social cognition         0.49      0.53      0.51        51
#             Software engineering         0.81      0.80      0.80        64
#                     Solar Energy         0.76      0.75      0.75        51
#                Southern blotting         1.00      0.99      0.99        74
#                  Sports Injuries         0.82      0.65      0.73        49
#              Sprains and Strains         0.90      0.68      0.78        28
#       State space representation         0.89      0.95      0.92        43
#               Stealth Technology         0.95      0.84      0.89        25
#            Strength of materials         0.88      0.92      0.90        50
#                Stress Management         0.91      0.79      0.85        78
#                Suspension Bridge         0.93      0.87      0.90        61
#             Symbolic computation         0.64      0.85      0.73        55
#            System identification         0.70      0.75      0.72        67
#                   Thermodynamics         0.52      0.62      0.57        69
#                  Water Pollution         0.92      0.87      0.90        70
#                      Weight Loss         0.78      0.82      0.80        51
#            computer-aided design         0.81      0.84      0.82        55
#                 network security         0.89      0.76      0.82        62
#
#                           accuracy                           0.72      6993
#                          macro avg       0.74      0.70      0.71      6993
#                       weighted avg       0.74      0.72      0.72      6993
#
#
# === Evaluating on label column: 'area' | N-gram range: (1, 2) ===
# /home/shirbern/.conda/envs/shir_env_22_may/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [18:45:37] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#
#                 Low Testosterone         0.98      0.95      0.96        42
#                         Lymphoma         0.79      0.63      0.70        30
#                   Machine design         0.80      0.81      0.80        48
#                 Machine learning         0.76      0.77      0.76        48
#        Manufacturing engineering         0.95      0.94      0.95        67
#            Materials Engineering         0.86      0.95      0.90        39
#                   Media violence         0.95      0.88      0.92        43
#                         Medicare         0.84      0.75      0.79        51
#                        Menopause         0.77      0.85      0.81        48
#                    Mental Health         0.30      0.34      0.32        29
#                  Microcontroller         0.91      0.79      0.85        73
#                         Migraine         0.57      0.52      0.55        23
#                Molecular biology         0.82      0.73      0.77       121
#               Multiple Sclerosis         0.80      0.72      0.76        39
#                    Myelofibrosis         0.63      0.74      0.68        23
#          Nonverbal communication         0.73      0.77      0.75        48
#                Northern blotting         0.96      0.98      0.97       101
#                Operating systems         0.95      0.95      0.95        58
#            Operational amplifier         0.92      0.81      0.86        59
#                   Osteoarthritis         0.85      0.75      0.80        44
#                     Osteoporosis         0.76      0.69      0.72        42
#               Overactive Bladder         0.89      0.88      0.89        58
#                   PID controller         0.94      0.96      0.95        78
#               Parallel computing         0.82      0.75      0.78        79
#                        Parenting         0.78      0.83      0.80        46
#              Parkinson's Disease         0.86      0.88      0.87        43
#                Person perception         0.60      0.56      0.58        77
#                Polycythemia Vera         0.70      0.26      0.38        27
#        Polymerase chain reaction         0.72      0.85      0.78        95
#                        Prejudice         0.64      0.64      0.64        61
#             Prenatal development         0.90      0.82      0.86        68
#                  Problem-solving         0.87      0.83      0.85        58
#               Prosocial behavior         0.78      0.70      0.74        46
#                        Psoriasis         0.67      0.70      0.68        20
#              Psoriatic Arthritis         0.61      0.46      0.52        24
#             Rainwater Harvesting         0.97      0.98      0.97        58
#             Relational databases         0.93      0.90      0.92        63
#                   Remote Sensing         0.82      0.87      0.85        63
#             Rheumatoid Arthritis         0.57      0.38      0.46        34
#                  Satellite radio         0.78      0.93      0.85        15
#                    Schizophrenia         0.71      0.50      0.59        68
#      Seasonal affective disorder         0.78      0.81      0.79        47
#                    Senior Health         0.93      1.00      0.96        13
#                Signal-flow graph         0.93      0.85      0.89        48
#                        Skin Care         0.98      0.89      0.93        46
#                   Smart Material         0.88      0.76      0.81        49
#                Smoking Cessation         0.74      0.72      0.73        36
#                 Social cognition         0.47      0.61      0.53        51
#             Software engineering         0.86      0.80      0.83        64
#                     Solar Energy         0.79      0.80      0.80        51
#                Southern blotting         1.00      0.96      0.98        74
#                  Sports Injuries         0.80      0.80      0.80        49
#              Sprains and Strains         0.88      0.82      0.85        28
#       State space representation         0.91      0.93      0.92        43
#               Stealth Technology         1.00      0.92      0.96        25
#            Strength of materials         0.94      0.88      0.91        50
#                Stress Management         0.89      0.83      0.86        78
#                Suspension Bridge         0.88      0.95      0.91        61
#             Symbolic computation         0.77      0.84      0.80        55
#            System identification         0.76      0.78      0.77        67
#                   Thermodynamics         0.81      0.80      0.80        69
#                  Water Pollution         0.86      0.89      0.87        70
#                      Weight Loss         0.80      0.84      0.82        51
#            computer-aided design         0.84      0.87      0.86        55
#                 network security         0.83      0.85      0.84        62
#
#                           accuracy                           0.79      6993
#                          macro avg       0.79      0.78      0.78      6993
#                       weighted avg       0.80      0.79      0.79      6993

# %% [markdown]
# ### Best configurations:

# %%
def run_ngram_experiment(ngram_range, train_df, val_df, test_df, label_encoder, label_column, seed=SEED):
    print(f"\n=== Evaluating on label column: '{label_column}' | N-gram range: {ngram_range} ===")

    # TF-IDF vectorization
    vectorizer = TfidfVectorizer(ngram_range=ngram_range, max_features=1000000)
    X_train = vectorizer.fit_transform(train_df["Abstract"])

    X_test  = vectorizer.transform(test_df["Abstract"])

    # Encode labels
    y_train = label_encoder.fit_transform(train_df[label_column])
    # y_val   = label_encoder.transform(val_df[label_column])
    y_test  = label_encoder.transform(test_df[label_column])

    # Train model
    model = XGBClassifier(random_state=seed, use_label_encoder=False, eval_metric="mlogloss")
    model.fit(X_train, y_train)

    # Evaluate on test
    test_preds = model.predict(X_test)
    test_acc = accuracy_score(y_test, test_preds)
    print(f"Test Accuracy: {test_acc:.4f}")
    print("Test Classification Report:")
    print(classification_report(y_test, test_preds, target_names=label_encoder.classes_))

# %%
label_encoder = LabelEncoder()

# Run the best congfiguration, therefore concat train and validation sets
concat_train_df = pd.concat([train_df, val_df], ignore_index=True)

# domain:
run_ngram_experiment((1, 2), concat_train_df, "-", test_df, label_encoder, "Domain")
# Out:
# === Evaluating on label column: 'Domain' | N-gram range: (1, 2) ===
# /home/shirbern/.conda/envs/shir_env_22_may/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:58] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Test Accuracy: 0.8948
# Test Classification Report:
#                precision    recall  f1-score   support
#
#           CS        0.92      0.94      0.93       970
#        Civil        0.94      0.89      0.91       633
#          ECE        0.94      0.93      0.93       807
#          MAE        0.94      0.85      0.89       494
#      Medical        0.86      0.92      0.89      2166
#  Psychology         0.88      0.83      0.85      1072
# biochemistry        0.89      0.85      0.87       851
#
#      accuracy                           0.89      6993
#     macro avg       0.91      0.89      0.90      6993
#  weighted avg       0.90      0.89      0.89      6993
#
#
# === Evaluating on label column: 'area' | N-gram range: (1, 2) ===
# /home/shirbern/.conda/envs/shir_env_22_may/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:22:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
label_encoder = LabelEncoder()

# Run the best congfiguration, therefore concat train and validation sets
concat_train_df = pd.concat([train_df, val_df], ignore_index=True)

# area:
run_ngram_experiment((1, 2), concat_train_df, "-", test_df, label_encoder, "area")
# Out:
# === Evaluating on label column: 'area' | N-gram range: (1, 2) ===
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [06:43:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Test Accuracy: 0.8001
# Test Classification Report:
#                                     precision    recall  f1-score   support
#
#                        Addiction         0.76      0.61      0.67        46
#                 Algorithm design         0.80      0.75      0.77        55
#                        Allergies         1.00      0.89      0.94        53
#              Alzheimer's Disease         0.75      0.80      0.77        55
#             Ambient Intelligence         0.72      0.75      0.73        55
#         Analog signal processing         0.81      0.85      0.83        59
#           Ankylosing Spondylitis         0.67      0.60      0.63        40
#  Antisocial personality disorder         0.93      0.83      0.88        47
#                          Anxiety         0.45      0.48      0.47        42
#                           Asthma         0.73      0.69      0.71        52
#                Atopic Dermatitis         0.70      0.52      0.60        44
#              Atrial Fibrillation         0.90      0.90      0.90        40
#                        Attention         0.63      0.73      0.68        71
#                           Autism         0.65      0.63      0.64        54
#                   Bioinformatics         0.89      0.74      0.81        54
#                 Bipolar Disorder         0.79      0.58      0.67        38
#                    Birth Control         0.88      0.86      0.87        58
#  Borderline personality disorder         0.65      0.55      0.60        65
#                           Cancer         0.51      0.63      0.56        63
#                     Cell biology         0.77      0.73      0.75        78
#                      Child abuse         0.77      0.76      0.77        67
#                Children's Health         0.91      0.93      0.92        43
#                Computer graphics         0.92      0.84      0.88        68
#             Computer programming         0.91      0.91      0.91        68
#                  Computer vision         0.82      0.83      0.82        64
#          Construction Management         0.95      0.93      0.94        61
#              Control engineering         0.79      0.81      0.80        27
#                  Crohn's Disease         0.96      0.89      0.93        28
#                     Cryptography         0.75      0.88      0.81        57
#                  Data structures         0.85      0.85      0.85        54
#                         Dementia         0.50      0.56      0.53        32
#                       Depression         0.35      0.39      0.37        92
#                         Diabetes         0.55      0.63      0.59        41
#                  Digital control         0.75      0.75      0.75        71
#            Distributed computing         0.69      0.86      0.77        50
#                 Eating disorders         0.88      0.80      0.84        56
#                   Electric motor         0.85      0.89      0.87        57
#              Electrical circuits         0.84      0.90      0.87        59
#             Electrical generator         0.97      0.97      0.97        34
#               Electrical network         0.98      0.93      0.95        55
#                      Electricity         0.78      0.83      0.80        75
#          Emergency Contraception         0.76      0.78      0.77        40
#                       Enzymology         0.79      0.88      0.83        90
#                   False memories         0.84      0.92      0.88        51
#                  Fluid mechanics         0.64      0.74      0.68        57
#                 Fungal Infection         0.94      0.92      0.93        53
#                     Gender roles         0.96      0.94      0.95        47
#                         Genetics         0.53      0.74      0.62        84
#                       Geotextile         0.98      0.93      0.95        57
#                   Green Building         0.94      0.93      0.94        70
#                         HIV/AIDS         0.93      0.89      0.91        47
#                         Headache         0.76      0.78      0.77        54
#                    Healthy Sleep         1.00      0.88      0.93        16
#                    Heart Disease         0.57      0.58      0.57        45
#                      Hepatitis C         0.76      0.74      0.75        39
#            Hereditary Angioedema         0.89      0.94      0.91        17
#                 Human Metabolism         0.93      0.90      0.92        92
#                       Hydraulics         0.91      0.74      0.81        68
#                   Hypothyroidism         0.90      0.92      0.91        49
#    Idiopathic Pulmonary Fibrosis         0.90      0.81      0.85        43
#                 Image processing         0.71      0.80      0.76        56
#                       Immunology         0.58      0.73      0.65        93
#       Internal combustion engine         0.94      0.85      0.89        73
#         Irritable Bowel Syndrome         0.84      0.67      0.75        46
#                       Leadership         0.89      0.92      0.91        52
#                 Low Testosterone         0.95      0.90      0.93        42
#                         Lymphoma         0.94      0.74      0.83        43
#                   Machine design         0.87      0.87      0.87        63
#                 Machine learning         0.80      0.81      0.81        64
#        Manufacturing engineering         0.88      0.92      0.90        38
#            Materials Engineering         0.84      0.86      0.85        36
#                   Media violence         0.75      0.85      0.80        54
#                         Medicare         0.83      0.74      0.78        34
#                        Menopause         0.83      0.85      0.84        61
#                    Mental Health         0.48      0.50      0.49        24
#                  Microcontroller         0.88      0.80      0.84        61
#                         Migraine         0.56      0.42      0.48        24
#                Molecular biology         0.71      0.74      0.73        98
#               Multiple Sclerosis         0.83      0.60      0.70        40
#                    Myelofibrosis         0.74      0.63      0.68        27
#          Nonverbal communication         0.72      0.68      0.70        57
#                Northern blotting         1.00      1.00      1.00       111
#                Operating systems         0.95      0.86      0.90        66
#            Operational amplifier         0.87      0.85      0.86        71
#                   Osteoarthritis         0.90      0.74      0.81        50
#                     Osteoporosis         0.78      0.87      0.82        52
#               Overactive Bladder         0.90      0.92      0.91        49
#                   PID controller         0.93      0.89      0.91        57
#               Parallel computing         0.84      0.82      0.83        65
#                        Parenting         0.70      0.76      0.73        41
#              Parkinson's Disease         0.83      0.88      0.85        57
#                Person perception         0.54      0.78      0.64        46
#                Polycythemia Vera         0.69      0.50      0.58        22
#        Polymerase chain reaction         0.79      0.85      0.82       126
#                        Prejudice         0.76      0.73      0.74        51
#             Prenatal development         0.90      0.80      0.85        66
#                  Problem-solving         0.87      0.94      0.90        63
#               Prosocial behavior         0.85      0.71      0.77        65
#                        Psoriasis         0.78      0.58      0.67        24
#              Psoriatic Arthritis         0.64      0.61      0.62        23
#             Rainwater Harvesting         0.90      0.98      0.94        56
#             Relational databases         0.85      0.98      0.91        48
#                   Remote Sensing         0.83      0.83      0.83        48
#             Rheumatoid Arthritis         0.58      0.45      0.51        31
#                  Satellite radio         1.00      0.88      0.94        25
#                    Schizophrenia         0.56      0.56      0.56        59
#      Seasonal affective disorder         0.71      0.67      0.69        48
#                    Senior Health         0.89      0.94      0.91        17
#                Signal-flow graph         0.92      0.94      0.93        36
#                        Skin Care         0.90      0.93      0.92        59
#                   Smart Material         0.92      0.80      0.86        56
#                Smoking Cessation         0.79      0.77      0.78        39
#                 Social cognition         0.49      0.55      0.52        44
#             Software engineering         0.92      0.84      0.88        56
#                     Solar Energy         0.85      0.85      0.85        68
#                Southern blotting         1.00      0.95      0.97        79
#                  Sports Injuries         0.86      0.92      0.89        62
#              Sprains and Strains         0.83      0.60      0.70        25
#       State space representation         0.89      0.87      0.88        55
#               Stealth Technology         1.00      0.94      0.97        18
#            Strength of materials         0.89      0.91      0.90        46
#                Stress Management         0.81      0.79      0.80        53
#                Suspension Bridge         0.92      0.82      0.87        67
#             Symbolic computation         0.86      0.97      0.91        58
#            System identification         0.74      0.66      0.70        65
#                   Thermodynamics         0.75      0.85      0.80        62
#                  Water Pollution         0.85      0.83      0.84        77
#                      Weight Loss         0.85      0.88      0.87        60
#            computer-aided design         0.87      0.78      0.82        51
#                 network security         0.83      0.85      0.84        87
#
#                           accuracy                           0.80      6993
#                          macro avg       0.81      0.79      0.80      6993
#                       weighted avg       0.81      0.80      0.80      6993
